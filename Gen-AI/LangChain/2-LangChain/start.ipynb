# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPEN_AI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1")

# %%
result = llm.invoke("What is generative AI")
print(result)
# Out:
# content="**Generative AI** refers to a type of artificial intelligence designed to create new content or data that is similar to what it has been trained on. Unlike traditional AI, which often focuses on analyzing or classifying existing data, generative AI can **generate** new text, images, music, code, videos, and more.\n\n### How does it work?\nGenerative AI models—like GPT (for text), DALL-E (for images), or Jukebox (for music)—learn patterns from large datasets. Once trained, they use this knowledge to create new content that resembles their training data.\n\n### Examples\n- **Text Generation:** ChatGPT writing stories or answering questions.\n- **Image Creation:** DALL-E generating images from text prompts.\n- **Music Composition:** AI tools generating original songs.\n- **Code Generation:** AI tools writing programming code from natural language instructions.\n\n### Common Generative AI Technologies\n- **Large Language Models (LLMs):** Like OpenAI's GPT models, trained on massive text datasets.\n- **Generative Adversarial Networks (GANs):** Neural networks that learn to generate realistic images or other types of data.\n- **Diffusion Models:** Used in advanced image generation (e.g., Stable Diffusion).\n\n### Applications\n- Content creation (writing, art, music)\n- Data augmentation for training AI systems\n- Video game design\n- Product design and prototyping\n- Personalized learning and recommendations\n\n### In summary:\nGenerative AI is a field of artificial intelligence that can **create new things**—from written language to visual art—by learning from and mimicking examples in its training data." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 332, 'prompt_tokens': 12, 'total_tokens': 344, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_d38c7f4fa7', 'id': 'chatcmpl-CYiKYLTYTrz6VKmWB1pLasoxc2vll', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--2dcaa3ee-340a-416b-8561-3bca92f9c478-0' usage_metadata={'input_tokens': 12, 'output_tokens': 332, 'total_tokens': 344, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
##ChatPrompt templates
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user", "{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
##Chain all the required areas like prompts llm etc
chain = prompt | llm
response = chain.invoke({"input": "Can you tell me about LangSmith"})
print(response)
# Out:
# content='Certainly! **LangSmith** is a developer tool and platform provided by **LangChain** that is designed to help you **debug, evaluate, monitor, and manage large language model (LLM) applications in production**. LangSmith effectively bridges the gap between local prototypes and production LLM apps by offering visibility, analytics, and management capabilities.\n\nHere’s a concise overview of what LangSmith is and its main features:\n\n---\n\n### What Is LangSmith?\n\n- **LangSmith** is a cloud-based (or self-hosted) platform.\n- Used for **tracing and debugging LLM chains/agents**, and for logging LLM interactions during development or in production.\n- Integrates tightly with the [LangChain](https://langchain.com/) Python/JS frameworks, but can be used independently.\n- Enables evaluation of LLM application quality (e.g., answer correctness, hallucination detection) using both automated and human feedback.\n- Offers tools to monitor, benchmark, and continuously improve LLM-powered applications.\n\n---\n\n### Key Features\n\n1. **Tracing & Debugging**\n   - Provides deep traces of LLM workflows (inputs, outputs, intermediate steps).\n   - Helps identify why an LLM app may be failing or behaving unexpectedly.\n   - Visualizes chains, agents, prompts, and their outputs step-by-step.\n\n2. **Evaluation (Testing)**\n   - Lets you define and run **evaluation datasets** for your prompts and chains.\n   - Supports both automatic evaluation (metrics, heuristics) and human review.\n   - Tracks performance and regressions over time.\n\n3. **Monitoring & Logging**\n   - Logs real user (production) runs as well as development/test runs.\n   - Detects anomalies, errors, and drift in application behavior.\n   - Helps answer questions like “which inputs are causing errors?” or “how is the app performance trending?”\n\n4. **Prompt & Chain Management**\n   - Version and manage prompts, chains, and their outputs.\n   - Compare different prompt versions, chains, or agents.\n\n5. **Integration**\n   - Built-in support for LangChain, but native Python and REST API support allows use with any LLM pipeline.\n   - Easy integration by adding a tracing handler to your LangChain app/code.\n   - Supports OpenAI, Anthropic, Azure, and many other LLM providers.\n\n---\n\n### Common Use Cases\n\n- **Development**: Debugging and iteratively improving your compositional LLM chains and prompts.\n- **Testing**: Creating evaluation sets and tracking model/chain changes.\n- **Production Monitoring**: Observing real user inputs, outputs, and errors.\n- **Collaboration**: Sharing traces, evaluations, and performance reports with teammates.\n\n---\n\n### Getting Started\n\n- Create a free/paid account at [LangSmith Platform](https://smith.langchain.com/).\n- Install the LangChain library and attach a LangSmith tracing callback handler.\n- View traces, logs, and evaluation results in the LangSmith web UI.\n\n**Official documentation:**  \nhttps://docs.smith.langchain.com/\n\n---\n\n**In summary:**  \nLangSmith is for anyone building and shipping LLM apps who needs transparency, debugging, and quality control throughout the lifecycle. It’s especially valuable if you use LangChain, but it’s general enough for other frameworks as well.\n\nLet me know if you want a sample code snippet, a quick getting started guide, or have specific usage questions!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 692, 'prompt_tokens': 32, 'total_tokens': 724, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_d38c7f4fa7', 'id': 'chatcmpl-CYiTNCRPnMOgYZp9VaD88IGOP6YWL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--1b5f733a-13d3-4701-b3c9-fb67915b77ce-0' usage_me ...

# %%
###stroutput parser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
response = chain.invoke({"input": "Can you tell me about LangSmith"})
print(response)
